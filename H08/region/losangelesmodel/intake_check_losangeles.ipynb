# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pprint
h08dir = '/home/kajiyama/H08/H08_20230612'
SUF = '.gl5'
tag = '.ls5'
dtype = 'float32'
gl5shape = (2160, 4320)
hlfshape = (360, 720)
# (ny, nx)
rgnshape = (48, 48)
city_num = 12

# region geography
one = -120
two = -116
three = 32
four = 36
upperindex = (90-four)*12
lowerindex = (90-three)*12
leftindex = (180+one)*12
rightindex = (180+two)*12
print(upperindex, lowerindex, leftindex, rightindex)
# Out:
# 648 696 720 768

# %%
# intake file
intake = np.fromfile(f'/home/kajiyama/H08/H08_20230612/map/dat/cty_int_/fig/intake_display_{city_num:08}{SUF}', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
img_extent = (one, two, three, four)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap='jet')

# %%
# intake file
lndara = np.fromfile('/home/kajiyama/H08/H08_20230612/map/dat/lnd_ara_/lndara.CAMA.gl5', dtype='float32').reshape(gl5shape)

# crop
lndara_cropped = lndara[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
img_extent = (one, two, three, four)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(lndara_cropped, extent=img_extent, transform=projection, cmap='jet')

# %%
# intake file
rivout = np.fromfile('/home/kajiyama/H08/H08_20230612/riv/out/riv_out_/W5E5LR__20190000.gl5', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
img_extent = (one, two, three, four)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='jet')

# %%
# intake file
intake2 = np.fromfile(f'/home/kajiyama/H08/H08_20230612/map/dat/cty_int_/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake2_cropped = intake2[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
img_extent = (one, two, three, four)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(intake2_cropped, extent=img_extent, transform=projection, cmap='jet')
