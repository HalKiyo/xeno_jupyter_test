# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pprint
h08dir = '/home/kajiyama/H08/H08_20230612'
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
hlfshape = (360, 720)

# %%
# canal file
costline = np.fromfile('/home/kajiyama/H08/H08_20230612/map/out/des_pot_/Hist____20050000.CAMA.14000.0.08.gl5', dtype='float32').reshape(gl5shape)
costline_masked = np.ma.masked_where(costline == 0, costline)

projection = ccrs.PlateCarree(central_longitude=0)
img_extent = (-180, 180, -90, 90)
fig = plt.figure(figsize=(100,100))
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(costline_masked, extent=img_extent, transform=projection, cmap='rainbow')
plt.colorbar(im, orientation='horizontal')
