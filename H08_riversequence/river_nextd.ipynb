# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/kajiyama/H08/H08_20230612/map/out/riv_nxd_/rivnxd.CAMA.gl5'

# %%
dtype = 'float32' # 4バイト

# %%
data = np.fromfile(path, dtype=dtype)

# %%
lonlat = data.reshape(2160, 4320)

# %%
#5to25
#95to110
#1degree=60minute then 5min=12grids
# 180*12 + 95*12=2160+1140 = 3300
# 110*12=1320 = 3480
# (90-25)*12=960
# (90-5)*12=1020

# %%
plt.imshow(lonlat, vmin=0, vmax=10000)
plt.colorbar()

# %%
tha = lonlat[800:1000, 3300:3480]

# %%
plt.imshow(tha, vmin=0, vmax=10000)
plt.colorbar()

# %%
upp = lonlat[900:930, 3355:3375]

# %%
plt.imshow(upp, vmin=0, vmax=100000)
plt.colorbar()
