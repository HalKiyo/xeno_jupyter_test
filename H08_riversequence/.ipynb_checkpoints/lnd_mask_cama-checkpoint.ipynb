# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/kajiyama/H08/H08_20230612/map/out/riv_ara_/rivara.CAMA.gl5'

# %%
dtype = 'float32' # 4バイト

# %%
data = np.fromfile(path, dtype=dtype)

# %%
lonlat = data.reshape(2160, 4320)

# %%
#5to25
#95to110
#1degree=60minute then 5min=12grids
# 180*12 + 95*12=2160+1140 = 3300
# 110*12=1320 = 3480
# (90-25)*12=960
# (90-5)*12=1020

# %%
plt.imshow(lonlat)
plt.colorbar()

# %%
tha = lonlat[800:1000, 3300:3480]

# %%
plt.imshow(tha)
plt.colorbar()

# %%
upp = lonlat[900:930, 3355:3375]

# %%
upp_masked = np.ma.masked_where(upp >= 1e20, upp)
plt.imshow(upp_masked, vmax=np.max(upp_masked))

# %%
plt.imshow(upp, vmin=0, vmax=np.max(upp))
plt.colorbar()

# %%
plt.imshow(upp, vmin=0, vmax=10, cmap='tab10')
plt.colorbar()

# %%
3355/12
# Out:
# 279.5833333333333

# %%
3375/12
# Out:
# 281.25
